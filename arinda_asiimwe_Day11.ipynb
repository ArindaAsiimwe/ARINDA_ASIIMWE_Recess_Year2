# %% [markdown]
# Machine learning
#
# Types of machine learning
# 1. Unsupervised learning
# 2. Supervised learning
# 3. Reinforcement learning
#
# Data preprocessing
# Data cleaning
#
# Steps
# 1. Check for:
# -duplicates - drop
#
# -wrong format -
# -wrong data - learn the patterns of the data
#
# -empty cells - Imputation if the missing values are less than the available, delete/remove if most columns are missing
#
# -missing data -remove/delete, Imputation(mean/median/mode), use forward/backward filling, KNN or Regression
#
# Exploratory Data Analysis
#
# Steps
# Descriptive statistics- using the describe()
# -measure of the Central Tendency; mean, median, mode
# -measure of spread; range, variance, standard deviation, interquatile range
#
# -skewness, kurtosis
#
# Data visualisation
# -histogram, distribution of a single variable
# -box plots, for identifying outliers
# -scatter plot, for examining the relationship between 2 variables
# -heat maps, for visualizing correlation matrics
#
#
# Tools for Data visualization
#
# Matplotlib - line, bar, scatter graphs, histogram
# Seaborn - themes, color palettes, looks for more attractive(graphs)
#
#
# Feature engineering
#  Selection Filter like chi-square, ANOVA
#  Wrapper- recursive features
#  Embedded Lasso regression
#  Feature scaling and normalisation
#  Data Spliting
#
#
# Training and evaluation of a model
#  Most common ratios, 20testing 80training, 30 70
#  Import Sckit-learn to split into training and testing
#
#
# Random state is used to shuffle the data before splitting it into a training and testing set.
#
#
# Cross validation - evaluate the performance of the data, multiple folds
#
#  Helps in reducing variations in model performance estimates
#  Provides a comprehensive evaluation of model performance
#
#
# Types are train/test we can use K-Fold Cross validation
#
#  Stratified K-fold- ensure our distribution of the target variable, particularly used in the imbalance datasets
#  Supervised learning algorithm
#
#   Regression - Linear, Polynomial
#   Classification - Logistic regression, KNN, Support Vector Machine, Decision Tress, Random Forest
#
#  Model Evaluation
#  Metrics: Accuracy, Precision, Recall, F1-Score
#  Confusion Matrix
#  AUC(Area Under Curve) and ROC(Receiver Operating Characteristics Curve)
# Summary of Supervised learning
#
#  Labeled data
#  Predict ouout for new points
#  Common task - Classification and Regression
#
#
# Summary of Unsupervised learning
#
#  Unlabeled data
#  Find hidden patterns of structure
#  Common task - Clustering, Dimensionality and Association Rule Learning
#
#
# difference
#  Supervised - learns from labeled dao predict outputs for new inputs
#  Unsupervised - learns from unlabeled data to identify pattrns and structures within data

# %%
import pandas as pd

df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
# Step1: DATA CLEANING

# %%
# check for null values

print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# check for duplicates

print(df.duplicated().sum())
# Out:
# 1

# %%
# drop the duplicates

df.drop_duplicates(inplace=True)

# %%
# check for duplicates again

print(df.duplicated().sum())
# Out:
# 0

# %%
# check the format

print(df.dtypes)
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB
# None

# %%
# Step2: EXPLORATORY DATA ANALYSIS

import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(df.describe())
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
# Distribution of target variable
plt.figure(figsize=(8, 6))
df['target'].value_counts().plot(kind='bar')
plt.title('Distribution of Target Variable')
plt.xlabel('Heart Disease')
plt.ylabel('Count')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %%
# Age distribution by target
plt.figure(figsize=(10, 6))
sns.boxplot(x='target', y='age', data=df)
plt.title('Age Distribution by Heart Disease')
plt.xlabel('Heart Disease')
plt.ylabel('Age')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %%
# Cholesterol levels by sex
plt.figure(figsize=(10, 6))
sns.boxplot(x='sex', y='chol', data=df)
plt.title('Cholesterol Levels by Sex')
plt.xlabel('Sex')
plt.ylabel('Cholesterol')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# %%
# Plot distribution for 'age'
plt.figure(figsize=(6, 4))
sns.histplot(df['age'], kde=True)
plt.title('Distribution of Age')
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Step3: MODEL PREDICTION ACCURACY

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Separate features and target
X = df.drop(columns=['target'])
y = df['target']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = DecisionTreeClassifier()
model.fit(X_train,y_train)
predictions = model.predict(X_test)

score = accuracy_score(y_test, predictions)
score
# Out:
# 0.8032786885245902
